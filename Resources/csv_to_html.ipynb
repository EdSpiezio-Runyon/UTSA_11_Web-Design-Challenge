# %%
# Dependencies
import pandas as pd

# %%
# Load the CSV file created in previous WeatherPy project into a Pandas DataFrame.
city_data_df = pd.read_csv("cities.csv").set_index("City_ID")

# Display sample data
city_data_df
# Out:
#                     City  Cloudiness Country        Date  Humidity      Lat  \
# City_ID
# 0                  Tiksi          60      RU  1667532890        98  71.6872
# 1                   Chui           1      UY  1667532891        80 -33.6971
# 2              Jyvaskyla         100      FI  1667532891        98  62.2415
# 3                Rikitea         100      PF  1667532779        70 -23.1203
# 4           Puerto Ayora          68      EC  1667532892        84  -0.7393
# ...                  ...         ...     ...         ...       ...      ...
# 565        Alice Springs           0      AU  1667533178        14 -23.7000
# 566                Aketi         100      CD  1667533178        98   2.7388
# 567      Puerto Ayacucho          95      VE  1667533178        89   5.6639
# 568          Bandarbeyla          60      SO  1667533179        73   9.4942
# 569          Bloomington         100      US  1667533022        78  44.8408
#
#               Lng  Max Temp  Wind Speed
# ...

# %%
# Display HTML table
print(city_data_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Tiksi</td>
#       <td>60</td>
#       <td>RU</td>
#       <td>1667532890</td>
#       <td>98</td>
#       <td>71.6872</td>
#       <td>128.8694</td>
#       <td>-3.73</td>
#       <td>7.40</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Chui</td>
#       <td>1</td>
#       <td>UY</td>
#       <td>1667532891</td>
#       <td>80</td>
#       <td>-33.6971</td>
# ...
